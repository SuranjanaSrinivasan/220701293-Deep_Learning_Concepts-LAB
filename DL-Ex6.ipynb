# %%
import numpy as np
from tensorflow.keras.datasets import imdb
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, SimpleRNN, Dense

# %%
max_words = 5000
max_len = 200

# %%
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=max_words)
X_train = pad_sequences(x_train, maxlen=max_len)
X_test = pad_sequences(x_test, maxlen=max_len)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 ━━━━━━━━━━━━━━━━━━━━ 10s 1us/step

# %%
model = Sequential()
model.add(Embedding(input_dim=max_words, output_dim=32))
model.add(SimpleRNN(32))
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
print("Training...")
model.fit(X_train, y_train, epochs=10, batch_size=64, validation_split=0.2)
loss, acc = model.evaluate(X_test, y_test)
print(f"\nTest Accuracy: {acc:.4f}")
# Out:
# Training...
# Epoch 1/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 10s 31ms/step - accuracy: 0.8984 - loss: 0.2604 - val_accuracy: 0.8504 - val_loss: 0.3627
# Epoch 2/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.9329 - loss: 0.1808 - val_accuracy: 0.8382 - val_loss: 0.4474
# Epoch 3/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 25ms/step - accuracy: 0.9633 - loss: 0.1100 - val_accuracy: 0.8366 - val_loss: 0.4739
# Epoch 4/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.9681 - loss: 0.0922 - val_accuracy: 0.8228 - val_loss: 0.5250
# Epoch 5/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.9829 - loss: 0.0571 - val_accuracy: 0.8232 - val_loss: 0.6127
# Epoch 6/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.9929 - loss: 0.0280 - val_accuracy: 0.8418 - val_loss: 0.6656
# Epoch 7/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.9855 - loss: 0.0461 - val_accuracy: 0.7900 - val_loss: 0.7331
# Epoch 8/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.9937 - loss: 0.0225 - val_accuracy: 0.7870 - val_loss: 0.7905
# Epoch 9/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.9808 - loss: 0.0561 - val_accuracy: 0.8038 - val_loss: 0.7687
# Epoch 10/10
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 8s 24ms/step - accuracy: 0.9984 - loss: 0.0093 - val_accuracy: 0.8238 - val_loss: 0.7729
# 782/782 ━━━━━━━━━━━━━━━━━━━━ 4s 6ms/step - accuracy: 0.8214 - loss: 0.7779
#
# Test Accuracy: 0.8214

# %%
word_index = imdb.get_word_index()
reverse_word_index = {v: k for (k, v) in word_index.items()}

# %%
def decode_review(review):
    return " ".join([reverse_word_index.get(i - 3, "?") for i in review])
sample_review = X_test[0]...
prediction = model.predict(sample_review.reshape(1, -1))[0][0]
print("\nReview text:", decode_review(x_test[0]))
print("Predicted Sentiment:", "Positive " if prediction > 0.5 else "Negative ")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 73ms/step
#
# Review text: ? please give this one a miss br br ? ? and the rest of the cast ? terrible performances the show is flat flat flat br br i don't know how michael ? could have allowed this one on his ? he almost seemed to know this wasn't going to work out and his performance was quite ? so all you ? fans give this a miss
# Predicted Sentiment: Negative
